# %%
import pandas as pd 
url='https://www.mondovo.com/keywords/travel-keywords'

# %%
import requests
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}
r = requests.get(url, headers=header)
dfs = pd.read_html(r.text)

# %%
# get the table
df1=dfs[1]

# %%
df=df1.rename(columns={1: "Travel Keywords", 2: "Global Monthly Search",3:"Global CPC",4:"Find Related keywords"})
df
# Out:
#         0                             Travel Keywords  Global Monthly Search  \
# 0    Rank                             Travel Keywords  Global Monthly Search
# 1       1  electronic system for travel authorization                1000000
# 2       2                             travel republic                1000000
# 3       3                            travel insurance                 673000
# 4       4                              travel insured                 673000
# ..    ...                                         ...                    ...
# 497   496                               travel by bus                   1600
# 498   497                              travel phrases                   1600
# 499   498                               travel chanel                   1600
# 500   499                              travel sayings                   1600
# 501   500                             travelers stock                   1600
#
# ...

# %%
# clean up the table
df=df[['Travel Keywords','Global Monthly Search','Global CPC']]

# %%
# drop first row since it's headers
df = df.iloc[1:]
df
# Out:
#                                 Travel Keywords Global Monthly Search  \
# 1    electronic system for travel authorization               1000000
# 2                               travel republic               1000000
# 3                              travel insurance                673000
# 4                                travel insured                673000
# 5                           traveling insurance                673000
# ..                                          ...                   ...
# 497                               travel by bus                  1600
# 498                              travel phrases                  1600
# 499                               travel chanel                  1600
# 500                              travel sayings                  1600
# 501                             travelers stock                  1600
#
#     Global CPC
# 1        $1.24
# 2        $0.09
# 3        $7.15
# 4        $7.15
# 5        $7.15
# ..         ...
# ...

# %%
# drop row 13 because there's no value
df=df.drop(13)
df
# Out:
#                                 Travel Keywords Global Monthly Search  \
# 1    electronic system for travel authorization               1000000
# 2                               travel republic               1000000
# 3                              travel insurance                673000
# 4                                travel insured                673000
# 5                           traveling insurance                673000
# ..                                          ...                   ...
# 497                               travel by bus                  1600
# 498                              travel phrases                  1600
# 499                               travel chanel                  1600
# 500                              travel sayings                  1600
# 501                             travelers stock                  1600
#
#     Global CPC
# 1        $1.24
# 2        $0.09
# 3        $7.15
# 4        $7.15
# 5        $7.15
# ..         ...
# ...

# %%
df.head(15)
# Out:
#                                Travel Keywords Global Monthly Search  \
# 1   electronic system for travel authorization               1000000
# 2                              travel republic               1000000
# 3                             travel insurance                673000
# 4                               travel insured                673000
# 5                          traveling insurance                673000
# 6                        defense travel system                673000
# 7                                      travels                550000
# 8                                 travel clubs                246000
# 9                                travel quotes                201000
# 10                          travel supermarket                201000
# 11                          traveler insurance                165000
# 12                             travel agencies                165000
# 14                            traveling agency                165000
# ...

# %%
# save to csv
df.to_csv('cleaned data/search_keywords.csv',index=False)
